# %%
hello world
# Out:
#   Cell In[1], line 1
#     hello world
#           ^
# SyntaxError: invalid syntax

# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello world")
# Out:
# hello world

# %%
name = "Enes"

# %%
type(name)
# Out:
# str

# %%
'Enes Karatas'
# Out:
# 'Enes Karatas'

# %%
"Enes'in Evi"
# Out:
# "Enes'in Evi"

# %%
name.capitalize()
# Out:
# 'Enes'

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
name.count("a")
# Out:
# 0

# %%
name.count("e")
# Out:
# 1

# %%
x = 10
y = 5

# %%
x + y
# Out:
# 15

# %%
z = x + y

# %%
z
# Out:
# 15

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'ENES'

# %%
name.count("E") # saymaya 0 dan baslar ve buyuk kucuk harf farki yoktur
# Out:
# 1

# %%
name.count("e")
# Out:
# 1

# %%
len(name) # length 1 baslar
# Out:
# 4

# %%
print("Enes Karatas")
# Out:
# Enes Karatas

# %%
print("Enes \nKaratas")
# Out:
# Enes
# Karatas

# %%
print("Enes \tKaratas")
# Out:
# Enes 	Karatas

# %%
# \n => new line
# escape characters
# \t => tab

# %%
# Index

# %%
myString = "hello python"

# %%
myString[0]
# Out:
# 'h'

# %%
myString[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 myString[12]
#
# IndexError: string index out of range

# %%
myName = "james hetfield"

# %%
len(myName)
# Out:
# 14

# %%
myName[13]
# Out:
# 'd'

# %%
myName[len(myName) - 1]
# Out:
# 'd'

# %%
myName[-1] # myName[len(myName) - 1]
# Out:
# 'd'

# %%
barcode = "ABCDE123123412875"

# %%
type(barcode[0])
# Out:
# str

# %%
name = "Enes"

# %%
surname = "Karatas"

# %%
fullName = name + surname

# %%
fullName
# Out:
# 'EnesKaratas'

# %%
fullName * 5
# Out:
# 'EnesKaratasEnesKaratasEnesKaratasEnesKaratasEnesKaratas'

# %%
fullName = name + " " + surname

# %%
fullName * 5
# Out:
# 'Enes KaratasEnes KaratasEnes KaratasEnes KaratasEnes Karatas'

# %%
fullName - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 fullName - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
barcode
# Out:
# 'ABCDE123123412875'

# %%
barcode [0] + barcode [1] + barcode [2]
# Out:
# 'ABC'

# %%
#barcode[#starting index:#stopping index:#stepping index]

# %%
barcode[3::]
# Out:
# 'DE123123412875'

# %%
barcode[:3:]
# Out:
# 'ABC'

# %%
barcode[::2]
# Out:
# 'ACE213185'

# %%
barcode
# Out:
# 'ABCDE123123412875'

# %%
barcode[3::]
# Out:
# 'DE123123412875'

# %%
barcode[:5:]
# Out:
# 'ABCDE'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode
# Out:
# 'ABCDE123123412875'

# %%
barcode[::-1]
# Out:
# '578214321321EDCBA'

# %%
name = "Enes Karatas"

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(sub[, start[, end]], /) method of builtins.str instance
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Raises ValueError when the substring is not found.

# %%
name.index("s")
# Out:
# 3

# %%
name.split()
# Out:
# ['Enes', 'Karatas']

# %%
type(name.split())
# Out:
# list
