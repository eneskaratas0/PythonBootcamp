# %%
3+8
# Out:
# 11

# %%
#Variables

# %%
900/7
# Out:
# 128.57142857142858

# %%
age = 50

# %%
age
# Out:
# 50

# %%
aget * 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 aget * 3
#
# NameError: name 'aget' is not defined

# %%
# data type

# %%
type

# %%
type(10)

# %%
# int -> integer

# %%
type(3.14)

# %%
# float -> floating point

# %%
pi = 3.14

# %%
x = -100

# %%
x + pi

# %%
x = 10

# %%
x = 20

# %%
x + 10

# %%
# camelCase => myFloat
# snake_case => my_float

# %%
myFloat = 1.34344245

# %%
40 / 4

# %%
type(40 / 4)

# %%
40 / 9

# %%
2 * 2 * 2 * 2 * 2

# %%
2 ** 5

# %%
10 % 3  # remainder
