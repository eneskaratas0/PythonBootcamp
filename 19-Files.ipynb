# %%
# %%writefile myfile.txt
# test1
# test2
# test3
# Out:
# Writing myfile.txt

# %%
myFile = open("myfile.txt")

# %%
myFile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1254'>

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3\n'

# %%
myFile.read()
# Out:
# ''

# %%
myFile.seek(0)
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3\n'

# %%
myFile.close()

# %%
with open("myFile.txt") as myFile:
    myContent = myFile.read()

# %%
myContent
# Out:
# 'test1\ntest2\ntest3\n'

# %%
with open("myFile.txt",mode="w") as myNewFile:
    myContent = myNewFile.write("test 4")

# %%
with open("myFile.txt",mode="r") as myFile2:
    myContent = myFile2.read()

# %%
myContent
# Out:
# 'test 4'

# %%
# w -> write , r -> read, a -> append

# %%
with open("myFile.txt",mode="a") as myNewFile3:
    myContent = myNewFile3.write("test 5")

# %%
with open("myFile.txt",mode="r") as myNewFile4:
    myContent = myNewFile4.read()

# %%
myContent
# Out:
# 'test 4test 5\ntest 5test 5'
