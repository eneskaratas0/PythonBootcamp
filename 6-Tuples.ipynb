# %%
myList = [10,"a","b",3.14]

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 'a', 'b', 3.14]

# %%
# tuple

# %%
myTuple = (10,"a","b",3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
myTuple[0] = 100 # immutability
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 myTuple[0] = 100 # immutability
#
# TypeError: 'tuple' object does not support item assignment

# %%
myTuple.index("a")
# Out:
# 1

# %%
myTuple.count("a")
# Out:
# 1
