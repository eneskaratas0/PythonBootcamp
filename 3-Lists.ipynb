# %%
myString = "hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %% [markdown]
# # list

# %%
myString[0] = "a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 myString[0] = "a"
#
# TypeError: 'str' object does not support item assignment

# %%
#immutable - immutability

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x =10 
y = 20
z =30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[0] = 100

# %%
# mutable, mutability

# %%
myList
# Out:
# [100, 20, 30]

# %%
len(myList)
# Out:
# 3

# %%
myList[len(myList) - 1]
# Out:
# 30

# %%
myList[-1]
# Out:
# 30

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 20, 30, 80]

# %%
myList.count(20)
# Out:
# 1

# %%
myList.index(80)
# Out:
# 3

# %%
myList.insert(1,35)

# %%
myList
# Out:
# [100, 35, 20, 30, 80]

# %%
myList.pop(3)
# Out:
# 30

# %%
myList
# Out:
# [100, 35, 20, 80]

# %%
myList.reverse()

# %%
myList
# Out:
# [80, 20, 35, 100]

# %%
myList.sort()

# %%
myList
# Out:
# [20, 35, 80, 100]

# %%
x = input("enter X")
# Out:
# enter X 20

# %%
x
# Out:
# '20'

# %%
y = input("enter Y")
# Out:
# enter Y 30

# %%
z = input("enter Z")
# Out:
# enter Z 50

# %%
inputList = []

# %%
help(inputList.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['20', '30', '50']

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString = "python"

# %%
int(myString)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 int(myString)
#
# ValueError: invalid literal for int() with base 10: 'python'

# %%
int(inputList[1]) * 2
# Out:
# 60

# %%
nameList = ["atil","atlas","a","b"]

# %%
type(nameList)
# Out:
# list

# %%
mixList = ["enes","karatas",10,20,30.1,20,5]

# %%
type(mixList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
# nestedList

# %%
myNestedList = [10,20,3.14,"enes",[1,2,3]]

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'enes', [1, 2, 3]]

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
smallList[1]
# Out:
# 2

# %%
myNestedList[4][1]
# Out:
# 2

# %%
firstList = [10,20,30,40,50,60,70,80]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
firstList[2::]
# Out:
# [30, 40, 50, 60, 70, 80]

# %%
firstList[:5:]
# Out:
# [10, 20, 30, 40, 50]

# %%
firstList[1:6:2]
# Out:
# [20, 40, 60]
