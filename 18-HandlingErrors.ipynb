# %%
age = input("enter age:")
# Out:
# enter age: 21

# %%
age
# Out:
# '21'

# %%
int(age) * 2
# Out:
# 42

# %%
#try - except

# %%
while True:
    try:
        myAge = int(input("enter age: "))
        print(myAge * 2)
        #break
    except:
        print("enter your age !!!")
    else:
        print("else executed")
        break
    finally:
        print("finally")
# Out:
# enter age:  enes
# enter your age !!!
# finally
# enter age:  21
# 42
# else executed
# finally

# %% [markdown]
# #
