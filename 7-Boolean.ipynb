# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
myBoolean = False

# %%
5 > 3
# Out:
# True

# %%
3 > 5
# Out:
# False

# %%
user_age = int(input("Yasinizi Giriniz: "))
# Out:
# Yasinizi Giriniz:  20

# %%
user_age > 18
# Out:
# True
