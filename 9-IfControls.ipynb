# %%
x = 5
y = 2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
y = 5

# %%
x >=y
# Out:
# True

# %%
x <= 5
# Out:
# True

# %%
x >= 5.0
# Out:
# True

# %%
x >= 5.001
# Out:
# False

# %%
x = 10

# %%
y = 8

# %%
x == y # Soldaki değer sağdaki değere eşit mi?
# Out:
# False

# %%
x != y # "Soldaki değer sağdaki değere eşit DEĞİL mi?"
# Out:
# True

# %%
2 > 1 and 3 > 2
# Out:
# True

# %%
2 > 1 and 3 < 2
# Out:
# False

# %%
True and True # tek bir tarafta False olmasi yeterli
# Out:
# True

# %%
False and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True or False # tek bir tarafta true olmasi yeterli
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
not 10 in [10,20,30]
# Out:
# False

# %%
5 not in [ 10,20,30]
# Out:
# True

# %%
my_superhero = "Batman"

# %%
my_superhero == "Batman"
# Out:
# True

# %%
if my_superhero == "Batman":
    #indenation
    print("Batman")
#########---------##########
print("Hello Python")
# Out:
# Batman
# Hello Python

# %%
if 3 > 4:
    print("Hello world")
    print("enes")

# %%
my_superhero = input("enter Superhero: ")
# Out:
# enter Superhero:  Superman

# %%
if my_superhero == "Superman":
    print("Superman")
elif my_superhero == "Batman":
    print("Batman")
elif my_superhero == "Aquaman":
    print("Aquaman")
elif my_superhero == "Ironman":
    print("Ironman")
else:
    print(":(")
# Out:
# Superman

# %%
my_age = 40

# %%
if my_age <= 18:
    print("age < 18")
elif my_age > 18 and my_age <= 30:
    print("18 - age - 30")
elif my_age > 30 and my_age <= 40:
    print("30 - age - 40")
else:
    print("age > 40")
# Out:
# 30 - age - 40

# %%
my_superhero = input("enter Superhero: ")
# Out:
# enter Superhero:  Aquaman

# %%
my_superhero_list = ["Spider Man","Iron Man","Thor","Black Widow"]

# %%
if my_superhero in my_superhero_list:
    print(":)")
else:
    print(":(")
# Out:
# :(
