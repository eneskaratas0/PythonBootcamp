# %%
#method vs functions

# %%
my_name = "Enes"

# %%
my_name.upper()
# Out:
# 'ENES'

# %%
my_name
# Out:
# 'Enes'

# %%
my_name_upper = my_name.upper()

# %%
my_name_upper
# Out:
# 'ENES'

# %%
help(my_name.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
#functions =>

# %%
def hello_python():
    print("hello")
    print("python")

# %%
hello_python
# Out:
# <function __main__.hello_python()>

# %%
hello_python()
# Out:
# hello
# python

# %%
#input

# %%
def hello_name(name):
    print(f"hello {name}")

# %%
hello_name
# Out:
# <function __main__.hello_name(name)>

# %%
hello_name("Enes")
# Out:
# hello Enes

# %%
def sum_example(num1, num2):
    print(num1 + num2)

# %%
sum_example(2,3)
# Out:
# 5

# %%
def hello_surname(surname="celik"):
    print(f"hello {surname}")

# %%
hello_surname()
# Out:
# hello celik

# %%
#return

# %%
def summation(num1,num2,num3):
    print(num1 + num2 + num3)

# %%
summation(10,2,20)
# Out:
# 32

# %%
x = summation(10,5,50)
# Out:
# 65

# %%
x

# %%
print(x)
# Out:
# None

# %%
type(x)
# Out:
# NoneType

# %%
def return_summation(num1,num2,num3):
    result = num1 + num2 + num3
    print(result)
    return  result # return dan sonra fonksiyonun isi biter

# %%
return_summation(20,5,50)
# Out:
# 75
# 75

# %%
x = return_summation(10,50,70)
# Out:
# 130

# %%
x
# Out:
# 130

# %%
def control_string(s):
    if s[0] == "a":
        print("a")

# %%
control_string("ahmet")
# Out:
# a

# %%
#args , kwargs (arguments , key words arguments)

# %%
def args_sum(*args):
    return sum(args)

# %%
args_sum(10,20,30,40,50)
# Out:
# 150

# %%
def args_example(*args):
    print(args)

# %%
args_example(123,50,70,80,)
# Out:
# (123, 50, 70, 80)

# %%
#kwargs

# %%
def kwargs_example(**kwargs):
    print(kwargs)

# %%
kwargs_example(apple=100,banana=150,melon=200)
# Out:
# {'apple': 100, 'banana': 150, 'melon': 200}

# %%
def kwargs_example_2(**kwargs):
    if "apple" in kwargs:
        print("appleeee")
    else:
        print(":(")

# %%
kwargs_example_2(banana=15)
# Out:
# :(

# %%
kwargs_example_2(apple=10,banana=15)
# Out:
# appleeee
